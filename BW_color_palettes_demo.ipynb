# %%
import matplotlib.pyplot as plt
import numpy as np
from BW_color_palettes import *

# %%
display_palettes(burke_palettes)

# %%
display_palettes(yalenus_palettes)

# %%
display_palettes(nusbtc)

# %%
display_palettes(oxford)

# %%
display_palettes(uni_themes)
